# %% [markdown]
# <a href="https://colab.research.google.com/github/VRachana2802/AIML2303A52335/blob/main/2303A52335.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3]
b=[3,4,5]
import numpy as np
a=np.sqrt(a)
b=np.array(b)
print(a)
# Out:
# [1.         1.41421356 1.73205081]

# %%
a=[1,2,3]
b=[3,4,5]
import numpy as np
a=np.array(a)
b=np.array(b)
print(a-b)
# Out:
# [-2 -2 -2]

# %%
a=[1,2,3,4]
b=[5,6,7,8]
import numpy as np
a=np.mean(a)
b=np.array(b)
print(a)
# Out:
# 2.5

# %%
a=[1,2,3,4]
b=[4,5,6,7]
import numpy as np
a=np.array(a)
b=np.mean(b)
print(b)
# Out:
# 5.5

# %%
a=[1,2,3,4]
b=[4,5,6,7]
import numpy as np
a=np.array(a)
b=np.std(b)
print(b)
# Out:
# 1.118033988749895

# %%
import numpy as np
a=np.array(a)
print(np.tan(45))
# Out:
# 1.6197751905438615

# %%
a=[1,2,3,4,5]
b=[3,4,5,6,7]
import numpy as np
a=np.array(a)
b=np.min(b)
print(b)
# Out:
# 3

# %%
a=[[1,2,3],[4,5,6],[8,10,11]]
b=[[2,3,4],[4,5,6],[4,6,7]]
print(a,b)
m=np.array(a)
print(m)
# Out:
# [[1, 2, 3], [4, 5, 6], [8, 10, 11]] [[2, 3, 4], [4, 5, 6], [4, 6, 7]]
# [[ 1  2  3]
#  [ 4  5  6]
#  [ 8 10 11]]

# %%
a=[[1,2,3],[4,5,6],[8,10,11]]
print(a)
m=np.linalg.matrix_rank(a)
print(m)
# Out:
# [[1, 2, 3], [4, 5, 6], [8, 10, 11]]
# 3

# %%
a=[[1,2,3],[2,3,4],[7,8,9]]
print(a)
m=np.linalg.eigvals(a)
print(m)
# Out:
# [[1, 2, 3], [2, 3, 4], [7, 8, 9]]
# [ 1.42620873e+01 -1.26208735e+00 -1.73958363e-15]

# %%
x=[1,2,3,4,5,6,7,8,9,3]
y=[2,3,4,5,6,7,8,9,2,4]
import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
x=[1,2,3,4,5,6,7,8,9,3]
y=[2,3,4,5,6,7,8,9,2,4]
import matplotlib.pyplot as plt
plt.plot(x,y,'b')

# %%
plt.scatter(x,y)

# %%
x=[2,3,4,5,6,7,8,9,2,6]
y=[4,5,6,7,8,9,3,5,3,3]
import matplotlib.pyplot as plt
plt.hist(x,5)
# Out:
# (array([3., 1., 3., 1., 2.]),
#  array([2. , 3.4, 4.8, 6.2, 7.6, 9. ]),
#  <BarContainer object of 5 artists>)

# %%
x=[1,2,3,4,5,6,7,8,9,3]
y=[2,3,4,5,6,7,8,9,2,4]
import matplotlib.pyplot as plt
plt.hist(x,6)
# Out:
# (array([2., 2., 1., 2., 1., 2.]),
#  array([1.        , 2.33333333, 3.66666667, 5.        , 6.33333333,
#         7.66666667, 9.        ]),
#  <BarContainer object of 6 artists>)

# %%
x=[1,2,3,4,5,6,7,8,9,3]
y=[2,3,4,5,6,7,8,9,2,4]
import matplotlib.pyplot as plt
plt.bar(x,5)
# Out:
# <BarContainer object of 10 artists>

# %%
x=[1,2,3,4,5,6,7,8,9,3]
y=[2,3,4,5,6,7,8,9,2,4]
import matplotlib.pyplot as plt
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b15eaaa0d30>,
# ...
#  [Text(1.097644815422134, 0.07194344429417662, ''),
#   Text(1.062518406696673, 0.28470095790278555, ''),
#   Text(0.9146165663805669, 0.6111272670256354, ''),
#   Text(0.5499999814184447, 0.9526279548909482, ''),
#   Text(-0.07194346356334992, 1.0976448141591655, ''),
#   Text(-0.7778174684082679, 0.7778174502021367, ''),
#   Text(-1.0976448158431236, -0.07194343787111851, ''),
#   Text(-0.5500000037163116, -0.9526279420172691, ''),
#   Text(0.6111272670256354, -0.9146165663805669, ''),
#   Text(1.0788638109550837, -0.21459934159142627, '')])

# %%
x=[1,2,3,4,5,6,7,8,9,3]
y=[2,3,4,5,6,7,8,9,2,4]
import matplotlib.pyplot as plt

# %%
import pandas as pd
d=pd.read_csv("/content/sample_data/california_housing_train.csv")
print(d)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
import pandas as pd
d=pd.read_csv("/content/sample_data/california_housing_train.csv")
print(d['latitude'])
x=d['longitude']
y=d['latitude']
plt.plot(x,y)
# Out:
# 0        34.19
# 1        34.40
# 2        33.69
# 3        33.64
# 4        33.57
#          ...
# 16995    40.58
# 16996    40.69
# 16997    41.84
# 16998    41.80
# 16999    40.54
# Name: latitude, Length: 17000, dtype: float64
