# %% [markdown]
# <a href="https://colab.research.google.com/github/VRachana2802/AIML2303A52335/blob/main/ass_7_2335.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
data = pd.read_csv('/content/Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['YearsExperience'].plot(kind='hist', bins=20, title='YearsExperience')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='YearsExperience', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['YearsExperience']
#   ys = series['Salary']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('YearsExperience', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('YearsExperience')
# _ = plt.ylabel('Salary')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['YearsExperience']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'YearsExperience'}, axis=1)
#               .sort_values('YearsExperience', ascending=True))
#   xs = counted['YearsExperience']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('YearsExperience', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('YearsExperience')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['YearsExperience'].plot(kind='line', figsize=(8, 4), title='YearsExperience')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Salary'].plot(kind='line', figsize=(8, 4), title='Salary')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
X = data[['YearsExperience']]
y = data['Salary']
print(X)
print(y)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
 plt.figure(figsize=(8,6))
 plt.scatter(X,y,color='blue',label='Datapoints')
 plt.title('YearsofExperiencevsSalary')
 plt.xlabel('Years of Experience')
 plt.ylabel('Salary')
 plt.legend()
 plt.grid(True)
 plt.show()

# %%
lin_reg=LinearRegression()
lin_reg.fit(X,y)
plt.figure(figsize=(8,6))
plt.scatter(X,y,color='blue',label='Datapoints')
plt.plot(X, lin_reg.predict(X),color='red',label='BestFitLine')
plt.title('YearsofExperiencevsSalarywithBestFitLine')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()

# %%
def evaluate_model(test_size):
    X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=test_size/100, random_state=42)
    lin_reg.fit(X_train, y_train) # Removed extra space at the beginning of this line
    y_pred = lin_reg.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    return mse, mae
mse_20, mae_20 = evaluate_model(20)
mse_25, mae_25 = evaluate_model(25)
print(f'MSE for 20% test size: {mse_20:.2f}, MAE for 20% test size: {mae_20:.2f}')
print(f'MSE for 25% testsize:{mse_25:.2f},MAEfor25%testsize:{mae_25:.2f}')
# Out:
# MSE for 20% test size: 49830096.86, MAE for 20% test size: 6286.45
# MSE for 25% testsize:38802588.99,MAEfor25%testsize:5057.00

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
data_dict ={
 'Feature1':[1.2, 2.4,3.5,4.1,1.9,3.7, 2.1,3.3,2.8,4.0],
 'Feature2':[2.3, 1.9,2.7,3.0,2.8,2.5, 3.2,2.4,3.1,3.3],
 'Feature3':[3.1, 2.8,1.5,3.6,2.5,1.9, 2.2,3.0,1.8,2.7],
 'Feature4':[4.2, 3.5,2.9,4.8,3.2,4.0, 4.1,4.5,3.6,4.9],
 'Target': [15.6, 13.1,12.4, 18.2,14.1,16.0,14.5,17.3,14.9, 19.2]
 }
data= pd.DataFrame(data_dict)
data.head()
# Out:
#    Feature1  Feature2  Feature3  Feature4  Target
# 0       1.2       2.3       3.1       4.2    15.6
# 1       2.4       1.9       2.8       3.5    13.1
# 2       3.5       2.7       1.5       2.9    12.4
# 3       4.1       3.0       3.6       4.8    18.2
# 4       1.9       2.8       2.5       3.2    14.1

# %%
 X =data[['Feature1', 'Feature2','Feature3','Feature4']]
 y =data['Target']
 print(X)
 print(y)
# Out:
#    Feature1  Feature2  Feature3  Feature4
# 0       1.2       2.3       3.1       4.2
# 1       2.4       1.9       2.8       3.5
# 2       3.5       2.7       1.5       2.9
# 3       4.1       3.0       3.6       4.8
# 4       1.9       2.8       2.5       3.2
# 5       3.7       2.5       1.9       4.0
# 6       2.1       3.2       2.2       4.1
# 7       3.3       2.4       3.0       4.5
# 8       2.8       3.1       1.8       3.6
# 9       4.0       3.3       2.7       4.9
# 0    15.6
# 1    13.1
# 2    12.4
# 3    18.2
# 4    14.1
# 5    16.0
# 6    14.5
# 7    17.3
# 8    14.9
# 9    19.2
# Name: Target, dtype: float64

# %%
plt.figure(figsize=(10,8))
for i,feature in enumerate(X.columns):
    plt.subplot(2,2,i+1) #This line was not indented
    plt.scatter(X[feature],y,color='blue')
    plt.title(f'{feature}vsTarget')
    plt.xlabel(feature)
    plt.ylabel('Target')
plt.tight_layout()
plt.show()

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
plt.figure(figsize=(8,8))
for feature in X.columns:
    plt.scatter(X[feature], y, color='blue', label='Data points')
    plt.plot(X[feature], lin_reg.predict(X), color='red', label='Best Fit Line')
    plt.title(f'{feature} vs Target')
    plt.xlabel(feature)
    plt.ylabel('Target')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def evaluate_model(test_size):
 X_train, X_test, y_train, y_test = train_test_split(X, y,
 test_size=test_size/100, random_state=42)
 lin_reg = LinearRegression()
 lin_reg.fit(X_train, y_train)
 y_pred = lin_reg.predict(X_test)
 mse = mean_squared_error(y_test, y_pred)
 mae = mean_absolute_error(y_test, y_pred)
 return mse, mae
 mse_20, mae_20 = evaluate_model(20)
 mse_30, mae_30 = evaluate_model(30)
 print(f'MSE for 20% test size: {mse_20:.2f}, MAE for 20% test size: {mae_20:.2f}')
 print(f'MSE for 30% test size: {mse_30:.2f}, MAE for 30% test size: {mae_30:.2f}')
