# %% [markdown]
# <a href="https://colab.research.google.com/github/VRachana2802/AIML2303A52335/blob/main/SML_ass_4_2335.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
d=pd.read_csv('/content/train.csv')
print(d)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
 y = d['price_range']
 print(y)
 print("")
 print("Droping...")
 print("")
 x = d.drop('price_range', axis=1)
 x
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64
#
# Droping...
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2   2         20       756  2549     9     7
# 1       0.7        136        3   6        905      1988  2631    17     3
# 2       0.9        145        5   6       1263      1716  2603    11     2
# 3       0.8        131        6   9       1216      1786  2769    16     8
# 4       0.6        141        2  14       1208      1212  1411     8     2
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1995    0.8        106        6  14       1222      1890   668    13     4
# 1996    0.2        187        4   3        915      1965  2032    11    10
# 1997    0.7        108        8   3        868      1632  3057     9     1
# 1998    0.1        145        5   5        336       670   869    18    10
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi
# 0            19        0             0     1
# 1             7        1             1     0
# 2             9        1             1     0
# 3            11        1             0     0
# 4            15        1             1     0
# ...         ...      ...           ...   ...
# 1995         19        1             1     0
# 1996         16        1             1     1
# 1997          5        1             1     0
# 1998         19        1             1     1
# 1999          2        1             1     1
#
# [2000 rows x 20 columns]

# %%
df = d - (d.min())/(d.max() - d.min())
df
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0        841.665331   0.0          2.0       0.0   1.0     0.0    6.967742
# 1       1020.665331   1.0          0.3       1.0   0.0     1.0   52.967742
# 2        562.665331   1.0          0.3       1.0   2.0     1.0   40.967742
# 3        614.665331   1.0          2.3       0.0   0.0     0.0    9.967742
# 4       1820.665331   1.0          1.0       0.0  13.0     1.0   43.967742
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995     793.665331   1.0          0.3       1.0   0.0     1.0    1.967742
# 1996    1964.665331   1.0          2.4       1.0   0.0     0.0   38.967742
# 1997    1910.665331   0.0          0.7       1.0   1.0     1.0   35.967742
# 1998    1511.665331   0.0          0.7       0.0   4.0     1.0   45.967742
# 1999     509.665331   1.0          1.8       1.0   5.0     1.0   44.967742
#
#          m_dep   mobile_wt   n_cores  ...  px_height     px_width  \
# 0     0.488889  187.333333  1.857143  ...       20.0   755.666222
# 1     0.588889  135.333333  2.857143  ...      905.0  1987.666222
# 2     0.788889  144.333333  4.857143  ...     1263.0  1715.666222
# 3     0.688889  130.333333  5.857143  ...     1216.0  1785.666222
# 4     0.488889  140.333333  1.857143  ...     1208.0  1211.666222
# ...        ...         ...       ...  ...        ...          ...
# 1995  0.688889  105.333333  5.857143  ...     1222.0  1889.666222
# 1996  0.088889  186.333333  3.857143  ...      915.0  1964.666222
# 1997  0.588889  107.333333  7.857143  ...      868.0  1631.666222
# 1998 -0.011111  144.333333  4.857143  ...      336.0   669.666222
# 1999  0.788889  167.333333  5.857143  ...      483.0   753.666222
#
#               ram       sc_h  sc_w  talk_time  three_g  touch_screen  wifi  \
# 0     2548.931587   8.642857   7.0  18.888889      0.0           0.0   1.0
# 1     2630.931587  16.642857   3.0   6.888889      1.0           1.0   0.0
# 2     2602.931587  10.642857   2.0   8.888889      1.0           1.0   0.0
# 3     2768.931587  15.642857   8.0  10.888889      1.0           0.0   0.0
# 4     1410.931587   7.642857   2.0  14.888889      1.0           1.0   0.0
# ...           ...        ...   ...        ...      ...           ...   ...
# 1995   667.931587  12.642857   4.0  18.888889      1.0           1.0   0.0
# 1996  2031.931587  10.642857  10.0  15.888889      1.0           1.0   1.0
# 1997  3056.931587   8.642857   1.0   4.888889      1.0           1.0   0.0
# 1998   868.931587  17.642857  10.0  18.888889      1.0           1.0   1.0
# 1999  3918.931587  18.642857   4.0   1.888889      1.0           1.0   1.0
#
#       price_range
# 0             1.0
# 1             2.0
# 2             2.0
# 3             2.0
# 4             1.0
# ...           ...
# 1995          0.0
# 1996          2.0
# 1997          3.0
# 1998          0.0
# 1999          3.0
#
# [2000 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
y_train
y_test
x_train
x_test
# Out:
# (1600, 20)
# (400, 20)
# (1600,)
# (400,)
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1860           1646     0          2.5         0   3       1          25
# 353            1182     0          0.5         0   7       1           8
# 1333           1972     0          2.9         0   9       0          14
# 905             989     1          2.0         0   4       0          17
# 1289            615     1          0.5         1   7       0          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 965            1379     0          0.5         1   1       0          19
# 1284            991     0          2.0         0   2       1          12
# 1739           1044     0          1.8         0   4       1          12
# 261             728     0          2.7         1   0       0          25
# 535            1185     0          1.9         0   0       0          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1860    0.6        200        2   5        211      1608   686     8     6
# 353     0.5        138        8  16        275       986  2563    19    17
# 1333    0.4        196        7  18        293       952  1316     8     1
# 905     0.2        166        3  19        256      1394  3892    18     7
# 1289    0.5        130        5   8       1021      1958  1906    14     5
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 965     0.3        134        8  17        387       671  3912    11     2
# 1284    0.3        158        5   6       1209      1678  2014    11     9
# 1739    0.7        104        6   5       1230      1263  1794    18     7
# 261     0.2         88        4   1        526      1529  2039     5     1
# 535     0.4        152        8   7        837      1642  2447    16     2
#
#       talk_time  three_g  touch_screen  wifi
# 1860         11        1             1     0
# 353          19        1             0     0
# 1333          8        1             1     0
# 905          19        1             1     0
# 1289          5        1             0     0
# ...         ...      ...           ...   ...
# 965          19        0             1     1
# 1284         10        1             0     0
# 1739         19        1             1     1
# 261          12        1             1     1
# 535           3        1             1     1
#
# [400 rows x 20 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
d=pd.read_csv('/content/sample_data/california_housing_train.csv')
print(d)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
d.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['longitude'].plot(kind='hist', bins=20, title='longitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['latitude'].plot(kind='hist', bins=20, title='latitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['housing_median_age'].plot(kind='hist', bins=20, title='housing_median_age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['total_rooms'].plot(kind='hist', bins=20, title='total_rooms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='longitude', y='latitude', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='latitude', y='housing_median_age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='housing_median_age', y='total_rooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='total_rooms', y='total_bedrooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['longitude'].plot(kind='line', figsize=(8, 4), title='longitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['latitude'].plot(kind='line', figsize=(8, 4), title='latitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['housing_median_age'].plot(kind='line', figsize=(8, 4), title='housing_median_age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['total_rooms'].plot(kind='line', figsize=(8, 4), title='total_rooms')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
d.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
 print("shape of each column")
 print("")
 d.shape
# Out:
# shape of each column
# (17000, 9)

# %%
 y = d['households']
 print(y)
 print("")
 print("Droping...")
 print("")
 x = d.drop('households', axis=1)
 x
# Out:
# 0        472.0
# 1        463.0
# 2        117.0
# 3        226.0
# 4        262.0
#          ...
# 16995    369.0
# 16996    465.0
# 16997    456.0
# 16998    478.0
# 16999    270.0
# Name: households, Length: 17000, dtype: float64
#
# Droping...
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  median_income  median_house_value
# 0          1015.0         1.4936             66900.0
# 1          1129.0         1.8200             80100.0
# 2           333.0         1.6509             85700.0
# 3           515.0         3.1917             73400.0
# 4           624.0         1.9250             65500.0
# ...           ...            ...                 ...
# 16995       907.0         2.3571            111400.0
# 16996      1194.0         2.5179             79000.0
# 16997      1244.0         3.0313            103600.0
# 16998      1298.0         1.9797             85800.0
# 16999       806.0         3.0147             94600.0
#
# [17000 rows x 8 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x['longitude'].plot(kind='hist', bins=20, title='longitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['latitude'].plot(kind='hist', bins=20, title='latitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['housing_median_age'].plot(kind='hist', bins=20, title='housing_median_age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x['total_rooms'].plot(kind='hist', bins=20, title='total_rooms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='longitude', y='latitude', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='latitude', y='housing_median_age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='housing_median_age', y='total_rooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x.plot(kind='scatter', x='total_rooms', y='total_bedrooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x['longitude'].plot(kind='line', figsize=(8, 4), title='longitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x['latitude'].plot(kind='line', figsize=(8, 4), title='latitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x['housing_median_age'].plot(kind='line', figsize=(8, 4), title='housing_median_age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x['total_rooms'].plot(kind='line', figsize=(8, 4), title='total_rooms')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
 null = d.isnull()
 null
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
#        population  households  median_income  median_house_value
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4           False       False          False               False
# ...           ...         ...            ...                 ...
# 16995       False       False          False               False
# 16996       False       False          False               False
# 16997       False       False          False               False
# 16998       False       False          False               False
# 16999       False       False          False               False
#
# [17000 rows x 9 columns]

# %%
df = d-(d.min())/(d.max() - d.min())
df
# Out:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -101.924542  30.731977           14.980392  5611.999947     1282.999845
# 1     -102.084542  30.941977           18.980392  7649.999947     1900.999845
# 2     -102.174542  30.231977           16.980392   719.999947      173.999845
# 3     -102.184542  30.181977           13.980392  1500.999947      336.999845
# 4     -102.184542  30.111977           19.980392  1453.999947      325.999845
# ...           ...        ...                 ...          ...             ...
# 16995 -111.874542  37.121977           51.980392  2216.999947      393.999845
# 16996 -111.884542  37.231977           35.980392  2348.999947      527.999845
# 16997 -111.914542  38.381977           16.980392  2676.999947      530.999845
# 16998 -111.914542  38.341977           18.980392  2671.999947      551.999845
# 16999 -111.964542  37.081977           51.980392  1819.999947      299.999845
#
#         population  households  median_income  median_house_value
# 0      1014.999916  471.999836       1.459125        66899.969074
# 1      1128.999916  462.999836       1.785525        80099.969074
# 2       332.999916  116.999836       1.616425        85699.969074
# 3       514.999916  225.999836       3.157225        73399.969074
# 4       623.999916  261.999836       1.890525        65499.969074
# ...            ...         ...            ...                 ...
# 16995   906.999916  368.999836       2.322625       111399.969074
# 16996  1193.999916  464.999836       2.483425        78999.969074
# 16997  1243.999916  455.999836       2.996825       103599.969074
# 16998  1297.999916  477.999836       1.945225        85799.969074
# 16999   805.999916  269.999836       2.980225        94599.969074
#
# [17000 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=30)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
y_train
y_test
x_train
x_test
# Out:
# (13600, 8)
# (3400, 8)
# (13600,)
# (3400,)
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10914    -120.85     37.51                 5.0       2899.0           745.0
# 6241     -118.25     34.23                37.0       1954.0           368.0
# 5904     -118.20     33.79                47.0       2549.0           626.0
# 9578     -119.35     36.52                39.0       3027.0           608.0
# 9444     -119.25     34.30                34.0       1189.0           220.0
# ...          ...       ...                 ...          ...             ...
# 12228    -121.47     38.55                52.0       1384.0           295.0
# 6639     -118.28     33.91                41.0        620.0           133.0
# 7850     -118.40     34.70                10.0       4122.0           814.0
# 4886     -118.10     34.01                42.0       1436.0           298.0
# 3618     -117.91     33.61                27.0       1797.0           343.0
#
#        population  median_income  median_house_value
# 10914      1593.0         2.2292            127500.0
# 6241        967.0         5.0862            261300.0
# 5904       1388.0         3.0135            192700.0
# 9578       2199.0         2.6445             62000.0
# 9444        445.0         4.8824            396400.0
# ...           ...            ...                 ...
# 12228       561.0         2.0242             94600.0
# 6639        642.0         2.6546            159600.0
# 7850       2164.0         4.2941            151600.0
# 4886       1005.0         3.4297            195800.0
# 3618        435.0         5.9196            500001.0
#
# [3400 rows x 8 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test['longitude'].plot(kind='hist', bins=20, title='longitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_test['latitude'].plot(kind='hist', bins=20, title='latitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_test['housing_median_age'].plot(kind='hist', bins=20, title='housing_median_age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_test['total_rooms'].plot(kind='hist', bins=20, title='total_rooms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test.plot(kind='scatter', x='longitude', y='latitude', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_test.plot(kind='scatter', x='latitude', y='housing_median_age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_test.plot(kind='scatter', x='housing_median_age', y='total_rooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# x_test.plot(kind='scatter', x='total_rooms', y='total_bedrooms', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test['longitude'].plot(kind='line', figsize=(8, 4), title='longitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x_test['latitude'].plot(kind='line', figsize=(8, 4), title='latitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x_test['housing_median_age'].plot(kind='line', figsize=(8, 4), title='housing_median_age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# x_test['total_rooms'].plot(kind='line', figsize=(8, 4), title='total_rooms')
# plt.gca().spines[['top', 'right']].set_visible(False)
